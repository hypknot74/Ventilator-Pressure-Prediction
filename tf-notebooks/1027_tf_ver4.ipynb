# %% [markdown]
# ## Import libraries

# %%
import os 

CUDA=0

NAME = '1027_tf_ver4'
OUTPUT_DIR = f'./results/{NAME}/'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
DATA_DIR = '../input/ventilator-pressure-prediction/'

# %%
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
#from tensorflow.keras.optimizers.schedules import CosineDecayRestarts
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, LayerNormalization
from tensorflow.keras.layers import Dense, Dropout, Input, Activation
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Load source datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_in__mean'] = df.groupby(['breath_id'])['u_in'].transform('mean')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"})\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df


print("Train data...\n")
train = add_features(train_df)

print("\nTest data...\n")
test = add_features(test_df)

del train_df
del test_df
gc.collect()
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
# 0

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id','one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

print(f"train: {train.shape} \ntest: {test.shape}")
# Out:
# train: (6036000, 64)
# test: (4024000, 64)

# %%
scaler = RobustScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 64)
# test: (50300, 80, 64)
# targets: (75450, 80)

# %%
pressure = targets.squeeze().reshape(-1,1).astype('float32')

P_MIN = np.min(pressure)
P_MAX = np.max(pressure)
P_STEP = (pressure[1] - pressure[0])[0]
print('Min pressure: {}'.format(P_MIN))
print('Max pressure: {}'.format(P_MAX))
print('Pressure step: {}'.format(P_STEP))
print('Unique values:  {}'.format(np.unique(pressure).shape[0]))

del pressure
gc.collect()
# Out:
# Min pressure: -1.8957443237304688
# Max pressure: 64.82099151611328
# Pressure step: 0.07030248641967773
# Unique values:  950
# 69

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 512
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# Running on 1 replicas
# Batch Size: 512

# %% [markdown]
# ## Keras DNN Model

# %%
def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    # x_emb = Dense(units=1024)(x_input)
    # x_emb = LayerNormalization()(x_emb)
    # x_emb = Activation('selu')(x_emb)
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(LSTM(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(LSTM(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(LSTM(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])

    x = Dense(units=1024, activation='selu')(x)    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
with tf.device(f'/device:GPU:{CUDA}'):
    model = dnn_model()
    model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 64)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 80, 1536)     5117952     input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 1024)     8392704     bidirectional[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 768)      4328448     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 80, 768)      3248640     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 80, 768)      0           bidirectional_2[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 768)      3072        multiply[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      2099200     bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 80, 512)      2099200     batch_normalization[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 80, 512)      0           bidirectional_3[0][0]
#                                                                  bidirectional_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 512)      2048        multiply_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 256)      656384      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 80, 256)      656384      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 256)      0           bidirectional_4[0][0]
#                                                                  bidirectional_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 256)      1024        multiply_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 80, 128)      164352      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80, 1920)     0           bidirectional_4[0][0]
#                                                                  bidirectional_5[0][0]
#                                                                  bidirectional_6[0][0]
#                                                                  bidirectional_7[0][0]
#                                                                  bidirectional_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 80, 1024)     1967104     concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80, 128)      131200      dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80, 1)        129         dense_1[0][0]
# ==================================================================================================
# Total params: 28,867,841
# Trainable params: 28,864,769
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file=OUTPUT_DIR+'Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
import wandb
from wandb.keras import WandbCallback




with tf.device(f'/device:GPU:{CUDA}'):
    VERBOSE = 1
    test_preds = []
    kf = KFold(n_splits=5, shuffle=True, random_state=2021)

    all_score = 0
    count = 0
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        run = wandb.init(project="Ventilator-Pressure-Public-tf", 
                     name=f'fold_{fold}',
                     config={"hyper": "parameter"},
                     group=NAME,
                    job_type='train')
        
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]

        model = dnn_model()

        #scheduler = CosineDecayRestarts(initial_learning_rate=1e-3, first_decay_steps=20, t_mul=1, alpha=1e-5)
        #optimizer = Adam(learning_rate=scheduler)

        model.compile(optimizer="adam", loss="mae")

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.85, 
                               patience=10, verbose=VERBOSE)

        # save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
        chk_point = ModelCheckpoint(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5', #options=save_locally, 
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=30, 
                           verbose=VERBOSE, mode="min", 
                           restore_best_weights=True)

        model.fit(X_train, y_train, 
                  validation_data=(X_valid, y_valid), 
                  epochs=300,
                  verbose=VERBOSE,
                  batch_size=BATCH_SIZE, 
                  callbacks=[lr, chk_point, es, WandbCallback()])

        # load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
        model = load_model(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5') #options=load_locally

        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
        score = mean_absolute_error(y_true, y_pred)
        print(f"Fold-{fold+1} | OOF Score: {score}")
        count += 1
        all_score += score

        test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
        
        run.finish()
        
    print(f'CV Score: {all_score/count:<.4f}')
# Out:
# wandb: Currently logged in as: hypknot (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/5ayp196g" target="_blank">fold_0</a></strong> to <a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Epoch 1/300
# 118/118 [==============================] - ETA: 0s - loss: 1.6975
# Epoch 00001: val_loss improved from inf to 1.52005, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 30s 253ms/step - loss: 1.6975 - val_loss: 1.5201
# Epoch 2/300
# 118/118 [==============================] - ETA: 0s - loss: 0.6423- ETA: 3
# Epoch 00002: val_loss improved from 1.52005 to 1.07720, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 222ms/step - loss: 0.6423 - val_loss: 1.0772
# Epoch 3/300
# 118/118 [==============================] - ETA: 0s - loss: 0.5267
# Epoch 00003: val_loss improved from 1.07720 to 0.61623, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 223ms/step - loss: 0.5267 - val_loss: 0.6162
# Epoch 4/300
# 118/118 [==============================] - ETA: 0s - loss: 0.5151
# Epoch 00004: val_loss improved from 0.61623 to 0.54620, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 223ms/step - loss: 0.5151 - val_loss: 0.5462
# Epoch 5/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4525- ETA: 3
# Epoch 00005: val_loss improved from 0.54620 to 0.43100, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.4525 - val_loss: 0.4310
# Epoch 6/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4457
# Epoch 00006: val_loss improved from 0.43100 to 0.40482, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 223ms/step - loss: 0.4457 - val_loss: 0.4048
# Epoch 7/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4189
# Epoch 00007: val_loss improved from 0.40482 to 0.38876, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.4189 - val_loss: 0.3888
# Epoch 8/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3901
# Epoch 00008: val_loss did not improve from 0.38876
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3901 - val_loss: 0.4100
# Epoch 9/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3780
# Epoch 00009: val_loss did not improve from 0.38876
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3780 - val_loss: 0.4447
# Epoch 10/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3751
# Epoch 00010: val_loss did not improve from 0.38876
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3751 - val_loss: 0.4635
# Epoch 11/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3607
# Epoch 00011: val_loss did not improve from 0.38876
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3607 - val_loss: 0.4226
# Epoch 12/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3556
# Epoch 00012: val_loss did not improve from 0.38876
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3556 - val_loss: 0.4500
# Epoch 13/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3535
# Epoch 00013: val_loss improved from 0.38876 to 0.34227, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.3535 - val_loss: 0.3423
# Epoch 14/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3441- ETA: 1s - lo
# Epoch 00014: val_loss improved from 0.34227 to 0.32403, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 225ms/step - loss: 0.3441 - val_loss: 0.3240
# Epoch 15/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3200
# Epoch 00015: val_loss did not improve from 0.32403
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3200 - val_loss: 0.3690
# Epoch 16/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3179- ETA: 1s - loss
# Epoch 00016: val_loss did not improve from 0.32403
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3179 - val_loss: 0.3272
# Epoch 17/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3107
# Epoch 00017: val_loss did not improve from 0.32403
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3107 - val_loss: 0.3382
# Epoch 18/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3033
# Epoch 00018: val_loss did not improve from 0.32403
# 118/118 [==============================] - 26s 217ms/step - loss: 0.3033 - val_loss: 0.3289
# Epoch 19/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2975
# Epoch 00019: val_loss did not improve from 0.32403
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2975 - val_loss: 0.3515
# Epoch 20/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3097
# Epoch 00020: val_loss improved from 0.32403 to 0.28791, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.3097 - val_loss: 0.2879
# Epoch 21/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2908- ETA: 0s - loss: 0.291
# Epoch 00021: val_loss improved from 0.28791 to 0.28570, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2908 - val_loss: 0.2857
# Epoch 22/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3019
# Epoch 00022: val_loss did not improve from 0.28570
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3019 - val_loss: 0.3347
# Epoch 23/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2801
# Epoch 00023: val_loss improved from 0.28570 to 0.27849, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.2801 - val_loss: 0.2785
# Epoch 24/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2820
# Epoch 00024: val_loss did not improve from 0.27849
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2820 - val_loss: 0.2914
# Epoch 25/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2708
# Epoch 00025: val_loss improved from 0.27849 to 0.26963, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.2708 - val_loss: 0.2696
# Epoch 26/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2720
# Epoch 00026: val_loss did not improve from 0.26963
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2720 - val_loss: 0.2945
# Epoch 27/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2702
# Epoch 00027: val_loss did not improve from 0.26963
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2702 - val_loss: 0.2712
# Epoch 28/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2570
# Epoch 00028: val_loss improved from 0.26963 to 0.25379, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2570 - val_loss: 0.2538
# Epoch 29/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2604
# Epoch 00029: val_loss did not improve from 0.25379
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2604 - val_loss: 0.2626
# Epoch 30/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2500
# Epoch 00030: val_loss improved from 0.25379 to 0.24840, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2500 - val_loss: 0.2484
# Epoch 31/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2407
# Epoch 00031: val_loss did not improve from 0.24840
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2407 - val_loss: 0.2620
# Epoch 32/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2542
# Epoch 00032: val_loss did not improve from 0.24840
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2542 - val_loss: 0.2931
# Epoch 33/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2625
# Epoch 00033: val_loss did not improve from 0.24840
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2625 - val_loss: 0.2548
# Epoch 34/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2544
# Epoch 00034: val_loss did not improve from 0.24840
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2544 - val_loss: 0.2707
# Epoch 35/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2411
# Epoch 00035: val_loss improved from 0.24840 to 0.24366, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2411 - val_loss: 0.2437
# Epoch 36/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2429
# Epoch 00036: val_loss did not improve from 0.24366
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2429 - val_loss: 0.2564
# Epoch 37/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2372- ETA: 2s
# Epoch 00037: val_loss did not improve from 0.24366
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2372 - val_loss: 0.2570
# Epoch 38/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2423
# Epoch 00038: val_loss did not improve from 0.24366
# 118/118 [==============================] - 26s 218ms/step - loss: 0.2423 - val_loss: 0.2496
# Epoch 39/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2300
# Epoch 00039: val_loss improved from 0.24366 to 0.23657, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2300 - val_loss: 0.2366
# Epoch 40/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2317
# Epoch 00040: val_loss improved from 0.23657 to 0.23225, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2317 - val_loss: 0.2323
# Epoch 41/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2241
# Epoch 00041: val_loss did not improve from 0.23225
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2241 - val_loss: 0.2353
# Epoch 42/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2250
# Epoch 00042: val_loss did not improve from 0.23225
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2250 - val_loss: 0.2545
# Epoch 43/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2315
# Epoch 00043: val_loss did not improve from 0.23225
# 118/118 [==============================] - 26s 218ms/step - loss: 0.2315 - val_loss: 0.2460
# Epoch 44/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2211
# Epoch 00044: val_loss improved from 0.23225 to 0.22996, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2211 - val_loss: 0.2300
# Epoch 45/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2145
# Epoch 00045: val_loss improved from 0.22996 to 0.22091, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2145 - val_loss: 0.2209
# Epoch 46/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2091
# Epoch 00046: val_loss improved from 0.22091 to 0.21894, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.2091 - val_loss: 0.2189
# Epoch 47/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2176
# Epoch 00047: val_loss did not improve from 0.21894
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2176 - val_loss: 0.2549
# Epoch 48/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2302
# Epoch 00048: val_loss did not improve from 0.21894
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2302 - val_loss: 0.2360
# Epoch 49/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2101
# Epoch 00049: val_loss did not improve from 0.21894
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2101 - val_loss: 0.2353
# Epoch 50/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2091
# Epoch 00050: val_loss improved from 0.21894 to 0.21738, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2091 - val_loss: 0.2174
# Epoch 51/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2088
# Epoch 00051: val_loss did not improve from 0.21738
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2088 - val_loss: 0.2191
# Epoch 52/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2042
# Epoch 00052: val_loss improved from 0.21738 to 0.20866, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.2042 - val_loss: 0.2087
# Epoch 53/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2114
# Epoch 00053: val_loss did not improve from 0.20866
# 118/118 [==============================] - 26s 218ms/step - loss: 0.2114 - val_loss: 0.2301
# Epoch 54/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2095- ETA: 2s -
# Epoch 00054: val_loss did not improve from 0.20866
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2095 - val_loss: 0.2284
# Epoch 55/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2065
# Epoch 00055: val_loss did not improve from 0.20866
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2065 - val_loss: 0.2268
# Epoch 56/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2069
# Epoch 00056: val_loss did not improve from 0.20866
# 118/118 [==============================] - 26s 218ms/step - loss: 0.2069 - val_loss: 0.2146
# Epoch 57/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1973
# Epoch 00057: val_loss improved from 0.20866 to 0.20736, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 225ms/step - loss: 0.1973 - val_loss: 0.2074
# Epoch 58/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1988- ETA: 1s - loss:
# Epoch 00058: val_loss did not improve from 0.20736
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1988 - val_loss: 0.2142
# Epoch 59/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2018
# Epoch 00059: val_loss did not improve from 0.20736
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2018 - val_loss: 0.2381
# Epoch 60/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2084
# Epoch 00060: val_loss did not improve from 0.20736
# 118/118 [==============================] - 26s 217ms/step - loss: 0.2084 - val_loss: 0.2292
# Epoch 61/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2033
# Epoch 00061: val_loss did not improve from 0.20736
# 118/118 [==============================] - 26s 218ms/step - loss: 0.2033 - val_loss: 0.2344
# Epoch 62/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1941
# Epoch 00062: val_loss did not improve from 0.20736
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1941 - val_loss: 0.2360
# Epoch 63/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1921
# Epoch 00063: val_loss improved from 0.20736 to 0.19880, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1921 - val_loss: 0.1988
# Epoch 64/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1906
# Epoch 00064: val_loss did not improve from 0.19880
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1906 - val_loss: 0.2085
# Epoch 65/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1830
# Epoch 00065: val_loss did not improve from 0.19880
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1830 - val_loss: 0.2001
# Epoch 66/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1862
# Epoch 00066: val_loss did not improve from 0.19880
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1862 - val_loss: 0.2038
# Epoch 67/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1772- - ETA: 3
# Epoch 00067: val_loss improved from 0.19880 to 0.19803, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1772 - val_loss: 0.1980
# Epoch 68/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1721- ETA: 2s
# Epoch 00068: val_loss improved from 0.19803 to 0.19170, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1721 - val_loss: 0.1917
# Epoch 69/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1753- ETA: 0s - loss: 0
# Epoch 00069: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1753 - val_loss: 0.1973
# Epoch 70/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1829
# Epoch 00070: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1829 - val_loss: 0.2187
# Epoch 71/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1765
# Epoch 00071: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1765 - val_loss: 0.2034
# Epoch 72/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1804- ETA: 0s - loss: 0.1
# Epoch 00072: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1804 - val_loss: 0.2162
# Epoch 73/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1870
# Epoch 00073: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1870 - val_loss: 0.1995
# Epoch 74/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1770
# Epoch 00074: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1770 - val_loss: 0.2100
# Epoch 75/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1816
# Epoch 00075: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1816 - val_loss: 0.2009
# Epoch 76/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1744-
# Epoch 00076: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1744 - val_loss: 0.1962
# Epoch 77/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1714
# Epoch 00077: val_loss did not improve from 0.19170
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1714 - val_loss: 0.1973
# Epoch 78/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1686
# Epoch 00078: val_loss improved from 0.19170 to 0.18253, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.1686 - val_loss: 0.1825
# Epoch 79/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1658
# Epoch 00079: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1658 - val_loss: 0.2079
# Epoch 80/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1852- ETA: 7s
# Epoch 00080: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1852 - val_loss: 0.1946
# Epoch 81/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1639
# Epoch 00081: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1639 - val_loss: 0.1916
# Epoch 82/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1660
# Epoch 00082: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1660 - val_loss: 0.1892
# Epoch 83/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1590
# Epoch 00083: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1590 - val_loss: 0.1882
# Epoch 84/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1691
# Epoch 00084: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1691 - val_loss: 0.1909
# Epoch 85/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1643
# Epoch 00085: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1643 - val_loss: 0.1897
# Epoch 86/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1568
# Epoch 00086: val_loss did not improve from 0.18253
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1568 - val_loss: 0.1847
# Epoch 87/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1531
# Epoch 00087: val_loss improved from 0.18253 to 0.17991, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.1531 - val_loss: 0.1799
# Epoch 88/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1555
# Epoch 00088: val_loss did not improve from 0.17991
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1555 - val_loss: 0.1920
# Epoch 89/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1664- ETA: 2s
# Epoch 00089: val_loss did not improve from 0.17991
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1664 - val_loss: 0.1993
# Epoch 90/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1599
# Epoch 00090: val_loss improved from 0.17991 to 0.17978, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1599 - val_loss: 0.1798
# Epoch 91/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1512- ETA: 2s
# Epoch 00091: val_loss did not improve from 0.17978
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1512 - val_loss: 0.1804
# Epoch 92/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1531
# Epoch 00092: val_loss did not improve from 0.17978
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1531 - val_loss: 0.1905
# Epoch 93/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1523
# Epoch 00093: val_loss improved from 0.17978 to 0.17850, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1523 - val_loss: 0.1785
# Epoch 94/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1642
# Epoch 00094: val_loss did not improve from 0.17850
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1642 - val_loss: 0.2536
# Epoch 95/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1826
# Epoch 00095: val_loss did not improve from 0.17850
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1826 - val_loss: 0.2068
# Epoch 96/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1683
# Epoch 00096: val_loss did not improve from 0.17850
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1683 - val_loss: 0.1960
# Epoch 97/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1572
# Epoch 00097: val_loss did not improve from 0.17850
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1572 - val_loss: 0.1823
# Epoch 98/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1476
# Epoch 00098: val_loss improved from 0.17850 to 0.17745, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 225ms/step - loss: 0.1476 - val_loss: 0.1774
# Epoch 99/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1546
# Epoch 00099: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1546 - val_loss: 0.2057
# Epoch 100/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1642
# Epoch 00100: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1642 - val_loss: 0.2022
# Epoch 101/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1510
# Epoch 00101: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1510 - val_loss: 0.1792
# Epoch 102/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1454
# Epoch 00102: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1454 - val_loss: 0.1906
# Epoch 103/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1562
# Epoch 00103: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1562 - val_loss: 0.1918
# Epoch 104/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1445
# Epoch 00104: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1445 - val_loss: 0.1984
# Epoch 105/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1447
# Epoch 00105: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1447 - val_loss: 0.1821
# Epoch 106/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1434
# Epoch 00106: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1434 - val_loss: 0.1874
# Epoch 107/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1434
# Epoch 00107: val_loss did not improve from 0.17745
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1434 - val_loss: 0.1836
# Epoch 108/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1411- ETA: 1s - loss:
# Epoch 00108: val_loss improved from 0.17745 to 0.17367, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.1411 - val_loss: 0.1737
# Epoch 109/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1463
# Epoch 00109: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1463 - val_loss: 0.1882
# Epoch 110/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1423
# Epoch 00110: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1423 - val_loss: 0.1907
# Epoch 111/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1420
# Epoch 00111: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1420 - val_loss: 0.1827
# Epoch 112/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1404
# Epoch 00112: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1404 - val_loss: 0.1788
# Epoch 113/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1324
# Epoch 00113: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1324 - val_loss: 0.1756
# Epoch 114/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1393
# Epoch 00114: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1393 - val_loss: 0.1977
# Epoch 115/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1723
# Epoch 00115: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1723 - val_loss: 0.1914
# Epoch 116/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1446
# Epoch 00116: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1446 - val_loss: 0.1783
# Epoch 117/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1358- ETA: 2s
# Epoch 00117: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1358 - val_loss: 0.1827
# Epoch 118/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1351
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
#
# Epoch 00118: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1351 - val_loss: 0.1856
# Epoch 119/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1252
# Epoch 00119: val_loss did not improve from 0.17367
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1252 - val_loss: 0.1754
# Epoch 120/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1257
# Epoch 00120: val_loss improved from 0.17367 to 0.16850, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.1257 - val_loss: 0.1685
# Epoch 121/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1184
# Epoch 00121: val_loss did not improve from 0.16850
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1184 - val_loss: 0.1688
# Epoch 122/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1172
# Epoch 00122: val_loss improved from 0.16850 to 0.16631, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1172 - val_loss: 0.1663
# Epoch 123/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1216
# Epoch 00123: val_loss did not improve from 0.16631
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1216 - val_loss: 0.1758
# Epoch 124/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1198
# Epoch 00124: val_loss improved from 0.16631 to 0.16607, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.1198 - val_loss: 0.1661
# Epoch 125/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1137
# Epoch 00125: val_loss improved from 0.16607 to 0.16569, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1137 - val_loss: 0.1657
# Epoch 126/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1137
# Epoch 00126: val_loss did not improve from 0.16569
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1137 - val_loss: 0.1659
# Epoch 127/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1128
# Epoch 00127: val_loss improved from 0.16569 to 0.16522, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1128 - val_loss: 0.1652
# Epoch 128/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1154
# Epoch 00128: val_loss did not improve from 0.16522
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1154 - val_loss: 0.1684
# Epoch 129/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1108
# Epoch 00129: val_loss did not improve from 0.16522
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1108 - val_loss: 0.1735
# Epoch 130/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1116
# Epoch 00130: val_loss improved from 0.16522 to 0.16493, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1116 - val_loss: 0.1649
# Epoch 131/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1100
# Epoch 00131: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1100 - val_loss: 0.1670
# Epoch 132/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1135
# Epoch 00132: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1135 - val_loss: 0.1693
# Epoch 133/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1075- ETA: 2s -
# Epoch 00133: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1075 - val_loss: 0.1666
# Epoch 134/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1067- ETA: 0s - loss: 0.10
# Epoch 00134: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1067 - val_loss: 0.1674
# Epoch 135/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1111
# Epoch 00135: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1111 - val_loss: 0.1729
# Epoch 136/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1079
# Epoch 00136: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1079 - val_loss: 0.1827
# Epoch 137/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1059
# Epoch 00137: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1059 - val_loss: 0.1674
# Epoch 138/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1048
# Epoch 00138: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1048 - val_loss: 0.1707
# Epoch 139/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1090
# Epoch 00139: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1090 - val_loss: 0.1690
# Epoch 140/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1047
# Epoch 00140: ReduceLROnPlateau reducing learning rate to 0.0007225000590551645.
#
# Epoch 00140: val_loss did not improve from 0.16493
# 118/118 [==============================] - 26s 217ms/step - loss: 0.1047 - val_loss: 0.1748
# Epoch 141/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0991- ETA: 1s - loss
# Epoch 00141: val_loss improved from 0.16493 to 0.16394, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.0991 - val_loss: 0.1639
# Epoch 142/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0965-
# Epoch 00142: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0965 - val_loss: 0.1649
# Epoch 143/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0955
# Epoch 00143: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0955 - val_loss: 0.1654
# Epoch 144/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0932
# Epoch 00144: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0932 - val_loss: 0.1649
# Epoch 145/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0925
# Epoch 00145: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0925 - val_loss: 0.1649
# Epoch 146/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0929- ETA: 1s - loss: 0.09 - ETA: 0s - loss: 0
# Epoch 00146: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0929 - val_loss: 0.1723
# Epoch 147/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0947
# Epoch 00147: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0947 - val_loss: 0.1651
# Epoch 148/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0917
# Epoch 00148: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0917 - val_loss: 0.1659
# Epoch 149/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0902
# Epoch 00149: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0902 - val_loss: 0.1656
# Epoch 150/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0953
# Epoch 00150: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0953 - val_loss: 0.1646
# Epoch 151/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0901- ETA: 0s - loss: 0.09
# Epoch 00151: ReduceLROnPlateau reducing learning rate to 0.0006141250254586339.
#
# Epoch 00151: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0901 - val_loss: 0.1667
# Epoch 152/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0880
# Epoch 00152: val_loss did not improve from 0.16394
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0880 - val_loss: 0.1652
# Epoch 153/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0860
# Epoch 00153: val_loss improved from 0.16394 to 0.16320, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.0860 - val_loss: 0.1632
# Epoch 154/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0842
# Epoch 00154: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0842 - val_loss: 0.1641
# Epoch 155/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0825
# Epoch 00155: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0825 - val_loss: 0.1665
# Epoch 156/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0840
# Epoch 00156: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0840 - val_loss: 0.1662
# Epoch 157/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0821
# Epoch 00157: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0821 - val_loss: 0.1650
# Epoch 158/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0814
# Epoch 00158: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0814 - val_loss: 0.1690
# Epoch 159/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0790
# Epoch 00159: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0790 - val_loss: 0.1633
# Epoch 160/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0815
# Epoch 00160: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0815 - val_loss: 0.1644
# Epoch 161/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0782
# Epoch 00161: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0782 - val_loss: 0.1647
# Epoch 162/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0798
# Epoch 00162: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0798 - val_loss: 0.1653
# Epoch 163/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0778
# Epoch 00163: ReduceLROnPlateau reducing learning rate to 0.0005220062914304435.
#
# Epoch 00163: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0778 - val_loss: 0.1657
# Epoch 164/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0732
# Epoch 00164: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0732 - val_loss: 0.1687
# Epoch 165/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0717
# Epoch 00165: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0717 - val_loss: 0.1640
# Epoch 166/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0708
# Epoch 00166: val_loss did not improve from 0.16320
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0708 - val_loss: 0.1659
# Epoch 167/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0704
# Epoch 00167: val_loss improved from 0.16320 to 0.16274, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 225ms/step - loss: 0.0704 - val_loss: 0.1627
# Epoch 168/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0708-
# Epoch 00168: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0708 - val_loss: 0.1680
# Epoch 169/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0707
# Epoch 00169: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0707 - val_loss: 0.1699
# Epoch 170/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0704
# Epoch 00170: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0704 - val_loss: 0.1643
# Epoch 171/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0690
# Epoch 00171: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0690 - val_loss: 0.1673
# Epoch 172/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0693
# Epoch 00172: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0693 - val_loss: 0.1659
# Epoch 173/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0685- ETA: 1s - loss:
# Epoch 00173: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0685 - val_loss: 0.1644
# Epoch 174/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0669
# Epoch 00174: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0669 - val_loss: 0.1669
# Epoch 175/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0687- ETA: 4s  - ETA: 1s - los
# Epoch 00175: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0687 - val_loss: 0.1702
# Epoch 176/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0671
# Epoch 00176: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0671 - val_loss: 0.1665
# Epoch 177/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0666
# Epoch 00177: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
#
# Epoch 00177: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0666 - val_loss: 0.1673
# Epoch 178/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0631
# Epoch 00178: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0631 - val_loss: 0.1632
# Epoch 179/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0607
# Epoch 00179: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0607 - val_loss: 0.1628
# Epoch 180/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0609
# Epoch 00180: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0609 - val_loss: 0.1643
# Epoch 181/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0590
# Epoch 00181: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0590 - val_loss: 0.1629
# Epoch 182/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 00182: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0587 - val_loss: 0.1632
# Epoch 183/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0587
# Epoch 00183: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 220ms/step - loss: 0.0587 - val_loss: 0.1641
# Epoch 184/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0585
# Epoch 00184: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0585 - val_loss: 0.1638
# Epoch 185/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0576
# Epoch 00185: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0576 - val_loss: 0.1638
# Epoch 186/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0581
# Epoch 00186: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0581 - val_loss: 0.1673
# Epoch 187/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0594- ET
# Epoch 00187: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
#
# Epoch 00187: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0594 - val_loss: 0.1637
# Epoch 188/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0562
# Epoch 00188: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0562 - val_loss: 0.1633
# Epoch 189/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0549
# Epoch 00189: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0549 - val_loss: 0.1643
# Epoch 190/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0537- ET
# Epoch 00190: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0537 - val_loss: 0.1638
# Epoch 191/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0537
# Epoch 00191: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0537 - val_loss: 0.1644
# Epoch 192/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0532
# Epoch 00192: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0532 - val_loss: 0.1665
# Epoch 193/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0537
# Epoch 00193: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0537 - val_loss: 0.1643
# Epoch 194/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0527
# Epoch 00194: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0527 - val_loss: 0.1641
# Epoch 195/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0526
# Epoch 00195: val_loss did not improve from 0.16274
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0526 - val_loss: 0.1650
# Epoch 196/300
# ...
# Epoch 00167: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0752 - val_loss: 0.1682
# Epoch 168/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0734
# Epoch 00168: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0734 - val_loss: 0.1675
# Epoch 169/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0730
# Epoch 00169: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0730 - val_loss: 0.1673
# Epoch 170/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0733
# Epoch 00170: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0733 - val_loss: 0.1678
# Epoch 171/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0712
# Epoch 00171: ReduceLROnPlateau reducing learning rate to 0.00044370535761117935.
#
# Epoch 00171: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0712 - val_loss: 0.1683
# Epoch 172/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0699
# Epoch 00172: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 221ms/step - loss: 0.0699 - val_loss: 0.1740
# Epoch 173/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0705- ET
# Epoch 00173: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0705 - val_loss: 0.1676
# Epoch 174/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0659
# Epoch 00174: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0659 - val_loss: 0.1678
# Epoch 175/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0682
# Epoch 00175: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0682 - val_loss: 0.1718
# Epoch 176/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0661
# Epoch 00176: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0661 - val_loss: 0.1671
# Epoch 177/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0642
# Epoch 00177: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0642 - val_loss: 0.1678
# Epoch 178/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0653
# Epoch 00178: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0653 - val_loss: 0.1676
# Epoch 179/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0648
# Epoch 00179: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0648 - val_loss: 0.1675
# Epoch 180/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0644
# Epoch 00180: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 220ms/step - loss: 0.0644 - val_loss: 0.1725
# Epoch 181/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0637
# Epoch 00181: ReduceLROnPlateau reducing learning rate to 0.00037714955396950245.
#
# Epoch 00181: val_loss did not improve from 0.16687
# 118/118 [==============================] - 26s 217ms/step - loss: 0.0637 - val_loss: 0.1675
# Epoch 182/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0616
# Epoch 00182: val_loss improved from 0.16687 to 0.16673, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_2C.h5
# 118/118 [==============================] - 27s 226ms/step - loss: 0.0616 - val_loss: 0.1667
# Epoch 183/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 00183: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0591 - val_loss: 0.1676
# Epoch 184/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0593
# Epoch 00184: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0593 - val_loss: 0.1676
# Epoch 185/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0572
# Epoch 00185: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0572 - val_loss: 0.1668
# Epoch 186/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0575
# Epoch 00186: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0575 - val_loss: 0.1689
# Epoch 187/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0581
# Epoch 00187: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0581 - val_loss: 0.1676
# Epoch 188/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0568
# Epoch 00188: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0568 - val_loss: 0.1675
# Epoch 189/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0561
# Epoch 00189: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0561 - val_loss: 0.1674
# Epoch 190/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0556
# Epoch 00190: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0556 - val_loss: 0.1698
# Epoch 191/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0566
# Epoch 00191: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0566 - val_loss: 0.1679
# Epoch 192/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0546
# Epoch 00192: ReduceLROnPlateau reducing learning rate to 0.0003205771208740771.
#
# Epoch 00192: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0546 - val_loss: 0.1672
# Epoch 193/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0531
# Epoch 00193: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0531 - val_loss: 0.1669
# Epoch 194/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0532
# Epoch 00194: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0532 - val_loss: 0.1679
# Epoch 195/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0513
# Epoch 00195: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0513 - val_loss: 0.1672
# Epoch 196/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0517
# Epoch 00196: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0517 - val_loss: 0.1678
# Epoch 197/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0508
# Epoch 00197: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0508 - val_loss: 0.1671
# Epoch 198/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0506
# Epoch 00198: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 220ms/step - loss: 0.0506 - val_loss: 0.1681
# Epoch 199/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0509
# Epoch 00199: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0509 - val_loss: 0.1683
# Epoch 200/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0515
# Epoch 00200: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0515 - val_loss: 0.1695
# Epoch 201/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0503
# Epoch 00201: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0503 - val_loss: 0.1671
# Epoch 202/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0507
# Epoch 00202: ReduceLROnPlateau reducing learning rate to 0.0002724905527429655.
#
# Epoch 00202: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0507 - val_loss: 0.1682
# Epoch 203/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0480
# Epoch 00203: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0480 - val_loss: 0.1676
# Epoch 204/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0474
# Epoch 00204: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0474 - val_loss: 0.1671
# Epoch 205/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 00205: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 219ms/step - loss: 0.0462 - val_loss: 0.1669
# Epoch 206/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0461
# Epoch 00206: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 220ms/step - loss: 0.0461 - val_loss: 0.1676
# Epoch 207/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0451
# Epoch 00207: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0451 - val_loss: 0.1673
# Epoch 208/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 00208: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0455 - val_loss: 0.1672
# Epoch 209/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0462
# Epoch 00209: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0462 - val_loss: 0.1674
# Epoch 210/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0459
# Epoch 00210: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0459 - val_loss: 0.1689
# Epoch 211/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0455
# Epoch 00211: val_loss did not improve from 0.16673
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0455 - val_loss: 0.1683
# Epoch 212/300
# 118/118 [==============================] - ETA: 0s - loss: 0.0450
# Epoch 00212: ReduceLROnPlateau reducing learning rate to 0.00023161696735769509.
#
# Epoch 00212: val_loss did not improve from 0.16673
# Restoring model weights from the end of the best epoch.
# 118/118 [==============================] - 26s 218ms/step - loss: 0.0450 - val_loss: 0.1679
# Epoch 00212: early stopping
# Fold-2 | OOF Score: 0.16673250563909864
# <br/>Waiting for W&B process to finish, PID 110463... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 330.64MB of 330.64MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▅▅▅▄▄▄▄▃▃▃▃▂▂▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>181</td></tr><tr><td>best_val_loss</td><td>0.16673</td></tr><tr><td>epoch</td><td>211</td></tr><tr><td>loss</td><td>0.045</td></tr><tr><td>lr</td><td>0.00027</td></tr><tr><td>val_loss</td><td>0.16793</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 1 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fold_1</strong>: <a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/3p7wwqve" target="_blank">https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/3p7wwqve</a><br/>
# Find logs at: <code>./wandb/run-20211027_021951-3p7wwqve/logs</code><br/>
#                     Syncing run <strong><a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/1um4ro8j" target="_blank">fold_2</a></strong> to <a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Epoch 1/300
# 118/118 [==============================] - ETA: 0s - loss: 1.6565
# Epoch 00001: val_loss improved from inf to 1.29948, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_3C.h5
# 118/118 [==============================] - 30s 252ms/step - loss: 1.6565 - val_loss: 1.2995
# Epoch 2/300
# 118/118 [==============================] - ETA: 0s - loss: 0.6537
# Epoch 00002: val_loss improved from 1.29948 to 0.89436, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_3C.h5
# 118/118 [==============================] - 26s 222ms/step - loss: 0.6537 - val_loss: 0.8944
# Epoch 3/300
# 118/118 [==============================] - ETA: 0s - loss: 0.5624
# Epoch 00003: val_loss improved from 0.89436 to 0.59748, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_3C.h5
# 118/118 [==============================] - 27s 226ms/step - loss: 0.5624 - val_loss: 0.5975
# Epoch 4/300
# 118/118 [==============================] - ETA: 0s - loss: 0.5021
# Epoch 00004: val_loss improved from 0.59748 to 0.46319, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_3C.h5
# 118/118 [==============================] - 26s 223ms/step - loss: 0.5021 - val_loss: 0.4632
# Epoch 5/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4498
# Epoch 00005: val_loss did not improve from 0.46319
# 118/118 [==============================] - 26s 217ms/step - loss: 0.4498 - val_loss: 0.6108
# Epoch 6/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4508
# Epoch 00006: val_loss improved from 0.46319 to 0.38162, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_3C.h5
# 118/118 [==============================] - 27s 227ms/step - loss: 0.4508 - val_loss: 0.3816
# Epoch 7/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4082
# Epoch 00007: val_loss did not improve from 0.38162
# 118/118 [==============================] - 26s 218ms/step - loss: 0.4082 - val_loss: 0.3865
# Epoch 8/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3888
# Epoch 00008: val_loss did not improve from 0.38162
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3888 - val_loss: 0.4126
# Epoch 9/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3937
# Epoch 00009: val_loss did not improve from 0.38162
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3937 - val_loss: 0.3859
# Epoch 10/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3602
# Epoch 00010: val_loss improved from 0.38162 to 0.33466, saving model to ./results/1027_tf_ver4/./Bidirect_LSTM_model_2021_3C.h5
# 118/118 [==============================] - 26s 224ms/step - loss: 0.3602 - val_loss: 0.3347
# Epoch 11/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3459
# Epoch 00011: val_loss did not improve from 0.33466
# 118/118 [==============================] - 26s 220ms/step - loss: 0.3459 - val_loss: 0.4095
# Epoch 12/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3337
# Epoch 00012: val_loss did not improve from 0.33466
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3337 - val_loss: 0.3395
# Epoch 13/300
# 103/118 [=========================>....] - ETA: 2s - loss: 0.3300

# %% [markdown]
# ## Create submission file

# %%
train = pd.read_csv(DATA_DIR + 'train.csv')
test = pd.read_csv(DATA_DIR + 'test.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')

unique_pressures = train["pressure"].unique()
sorted_pressures = np.sort(unique_pressures)
total_pressures_len = len(sorted_pressures)

def find_nearest(prediction):
    '''
    予測値は離散値であるため、学習データにある最も近い離散値に置き換える
    '''
    insert_idx = np.searchsorted(sorted_pressures, prediction)
    if insert_idx == total_pressures_len:
        # If the predicted value is bigger than the highest pressure in the train dataset,
        # return the max value.
        return sorted_pressures[-1]
    elif insert_idx == 0:
        # Same control but for the lower bound.
        return sorted_pressures[0]
    lower_val = sorted_pressures[insert_idx - 1]
    upper_val = sorted_pressures[insert_idx]
    return lower_val if abs(lower_val - prediction) < abs(upper_val - prediction) else upper_val

# %%
submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
submission["pressure"] = sum(test_preds)/5
submission.to_csv(OUTPUT_DIR+'mean_submission.csv', index=False)

# %%
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission["pressure"] = np.round((submission.pressure - P_MIN)/P_STEP) * P_STEP + P_MIN
submission["pressure"] = np.clip(submission.pressure, P_MIN, P_MAX)
submission["pressure"] = submission["pressure"].apply(find_nearest)
submission.to_csv(OUTPUT_DIR+'median_submission.csv', index=False)
