# %% [markdown]
# ## Import libraries

# %%
import os 

CUDA=1

NAME = '1030_tf_lstm+transformer'
OUTPUT_DIR = f'./results/{NAME}/'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
DATA_DIR = '../input/ventilator-pressure-prediction/'

# %%
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
#from tensorflow.keras.optimizers.schedules import CosineDecayRestarts
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, LayerNormalization
from tensorflow.keras.layers import Dense, Dropout, Input, Activation
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply
from tensorflow.keras import layers

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Load source datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_in__mean'] = df.groupby(['breath_id'])['u_in'].transform('mean')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"})\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df


print("Train data...\n")
train = add_features(train_df)

print("\nTest data...\n")
test = add_features(test_df)

del train_df
del test_df
gc.collect()
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
# 0

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id','one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

print(f"train: {train.shape} \ntest: {test.shape}")
# Out:
# train: (6036000, 64)
# test: (4024000, 64)

# %%
scaler = RobustScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 64)
# test: (50300, 80, 64)
# targets: (75450, 80)

# %%
pressure = targets.squeeze().reshape(-1,1).astype('float32')

P_MIN = np.min(pressure)
P_MAX = np.max(pressure)
P_STEP = (pressure[1] - pressure[0])[0]
print('Min pressure: {}'.format(P_MIN))
print('Max pressure: {}'.format(P_MAX))
print('Pressure step: {}'.format(P_STEP))
print('Unique values:  {}'.format(np.unique(pressure).shape[0]))

del pressure
gc.collect()
# Out:
# Min pressure: -1.8957443237304688
# Max pressure: 64.82099151611328
# Pressure step: 0.07030248641967773
# Unique values:  950
# 69

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 256
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# Running on 1 replicas
# Batch Size: 256

# %% [markdown]
# ## Keras DNN Model

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res


def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x_tf = x_input
        
    for _ in range(6):
        x_tf = transformer_encoder(x_tf, head_size=256, num_heads=8, ff_dim=1024, dropout=0.2)
    x_tf = Dense(units=128, activation='selu')(x_tf)    
    
    
    # x_emb = Dense(units=1024)(x_input)
    # x_emb = LayerNormalization()(x_emb)
    # x_emb = Activation('selu')(x_emb)
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(LSTM(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(LSTM(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(LSTM(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5, x_tf])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
with tf.device(f'/device:GPU:{CUDA}'):
    model = dnn_model()
    model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 80, 64)]     0
# __________________________________________________________________________________________________
# layer_normalization_36 (LayerNo (None, 80, 64)       128         input_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_18 (MultiH (None, 80, 64)       530496      layer_normalization_36[0][0]
#                                                                  layer_normalization_36[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 80, 64)       0           multi_head_attention_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_36 (TensorFlo [(None, 80, 64)]     0           dropout_36[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# layer_normalization_37 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_36[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 80, 1024)     66560       layer_normalization_37[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 80, 1024)     0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 80, 64)       65600       dropout_37[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_37 (TensorFlo [(None, 80, 64)]     0           conv1d_37[0][0]
#                                                                  tf_op_layer_AddV2_36[0][0]
# __________________________________________________________________________________________________
# layer_normalization_38 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_37[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_19 (MultiH (None, 80, 64)       530496      layer_normalization_38[0][0]
#                                                                  layer_normalization_38[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 80, 64)       0           multi_head_attention_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_38 (TensorFlo [(None, 80, 64)]     0           dropout_38[0][0]
#                                                                  tf_op_layer_AddV2_37[0][0]
# __________________________________________________________________________________________________
# layer_normalization_39 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_38[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 80, 1024)     66560       layer_normalization_39[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 80, 1024)     0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 80, 64)       65600       dropout_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_39 (TensorFlo [(None, 80, 64)]     0           conv1d_39[0][0]
#                                                                  tf_op_layer_AddV2_38[0][0]
# __________________________________________________________________________________________________
# layer_normalization_40 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_39[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_20 (MultiH (None, 80, 64)       530496      layer_normalization_40[0][0]
#                                                                  layer_normalization_40[0][0]
# __________________________________________________________________________________________________
# dropout_40 (Dropout)            (None, 80, 64)       0           multi_head_attention_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_40 (TensorFlo [(None, 80, 64)]     0           dropout_40[0][0]
#                                                                  tf_op_layer_AddV2_39[0][0]
# __________________________________________________________________________________________________
# layer_normalization_41 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_40[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 80, 1024)     66560       layer_normalization_41[0][0]
# __________________________________________________________________________________________________
# dropout_41 (Dropout)            (None, 80, 1024)     0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 80, 64)       65600       dropout_41[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_41 (TensorFlo [(None, 80, 64)]     0           conv1d_41[0][0]
#                                                                  tf_op_layer_AddV2_40[0][0]
# __________________________________________________________________________________________________
# layer_normalization_42 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_41[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_21 (MultiH (None, 80, 64)       530496      layer_normalization_42[0][0]
#                                                                  layer_normalization_42[0][0]
# __________________________________________________________________________________________________
# dropout_42 (Dropout)            (None, 80, 64)       0           multi_head_attention_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_42 (TensorFlo [(None, 80, 64)]     0           dropout_42[0][0]
#                                                                  tf_op_layer_AddV2_41[0][0]
# __________________________________________________________________________________________________
# layer_normalization_43 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_42[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 80, 1024)     66560       layer_normalization_43[0][0]
# __________________________________________________________________________________________________
# dropout_43 (Dropout)            (None, 80, 1024)     0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 80, 64)       65600       dropout_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_43 (TensorFlo [(None, 80, 64)]     0           conv1d_43[0][0]
#                                                                  tf_op_layer_AddV2_42[0][0]
# __________________________________________________________________________________________________
# layer_normalization_44 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_43[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_22 (MultiH (None, 80, 64)       530496      layer_normalization_44[0][0]
#                                                                  layer_normalization_44[0][0]
# __________________________________________________________________________________________________
# dropout_44 (Dropout)            (None, 80, 64)       0           multi_head_attention_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_44 (TensorFlo [(None, 80, 64)]     0           dropout_44[0][0]
#                                                                  tf_op_layer_AddV2_43[0][0]
# __________________________________________________________________________________________________
# layer_normalization_45 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_44[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 80, 1024)     66560       layer_normalization_45[0][0]
# __________________________________________________________________________________________________
# dropout_45 (Dropout)            (None, 80, 1024)     0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# bidirectional_27 (Bidirectional (None, 80, 1536)     5117952     input_5[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 80, 64)       65600       dropout_45[0][0]
# __________________________________________________________________________________________________
# bidirectional_28 (Bidirectional (None, 80, 1024)     8392704     bidirectional_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_45 (TensorFlo [(None, 80, 64)]     0           conv1d_45[0][0]
#                                                                  tf_op_layer_AddV2_44[0][0]
# __________________________________________________________________________________________________
# bidirectional_29 (Bidirectional (None, 80, 768)      4328448     bidirectional_28[0][0]
# __________________________________________________________________________________________________
# bidirectional_32 (Bidirectional (None, 80, 768)      3248640     bidirectional_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_46 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_45[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 80, 768)      0           bidirectional_29[0][0]
#                                                                  bidirectional_32[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_23 (MultiH (None, 80, 64)       530496      layer_normalization_46[0][0]
#                                                                  layer_normalization_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 80, 768)      3072        multiply_9[0][0]
# __________________________________________________________________________________________________
# dropout_46 (Dropout)            (None, 80, 64)       0           multi_head_attention_23[0][0]
# __________________________________________________________________________________________________
# bidirectional_30 (Bidirectional (None, 80, 512)      2099200     bidirectional_29[0][0]
# __________________________________________________________________________________________________
# bidirectional_33 (Bidirectional (None, 80, 512)      2099200     batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_46 (TensorFlo [(None, 80, 64)]     0           dropout_46[0][0]
#                                                                  tf_op_layer_AddV2_45[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 80, 512)      0           bidirectional_30[0][0]
#                                                                  bidirectional_33[0][0]
# __________________________________________________________________________________________________
# layer_normalization_47 (LayerNo (None, 80, 64)       128         tf_op_layer_AddV2_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 80, 512)      2048        multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 80, 1024)     66560       layer_normalization_47[0][0]
# __________________________________________________________________________________________________
# bidirectional_31 (Bidirectional (None, 80, 256)      656384      bidirectional_30[0][0]
# __________________________________________________________________________________________________
# bidirectional_34 (Bidirectional (None, 80, 256)      656384      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dropout_47 (Dropout)            (None, 80, 1024)     0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 80, 256)      0           bidirectional_31[0][0]
#                                                                  bidirectional_34[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 80, 64)       65600       dropout_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 80, 256)      1024        multiply_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_47 (TensorFlo [(None, 80, 64)]     0           conv1d_47[0][0]
#                                                                  tf_op_layer_AddV2_46[0][0]
# __________________________________________________________________________________________________
# bidirectional_35 (Bidirectional (None, 80, 128)      164352      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 80, 128)      8320        tf_op_layer_AddV2_47[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 2048)     0           bidirectional_31[0][0]
#                                                                  bidirectional_32[0][0]
#                                                                  bidirectional_33[0][0]
#                                                                  bidirectional_34[0][0]
#                                                                  bidirectional_35[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 80, 128)      262272      concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 80, 1)        129         dense_8[0][0]
# ==================================================================================================
# Total params: 31,017,601
# Trainable params: 31,014,529
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file=OUTPUT_DIR+'Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
import wandb
from wandb.keras import WandbCallback




with tf.device(f'/device:GPU:{CUDA}'):
    VERBOSE = 1
    test_preds = []
    kf = KFold(n_splits=10, shuffle=True, random_state=2021)

    all_score = 0
    count = 0
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        run = wandb.init(project="Ventilator-Pressure-Public-tf", 
                     name=f'fold_{fold}',
                     config={"hyper": "parameter"},
                     group=NAME,
                    job_type='train')
        
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]

        model = dnn_model()

        #scheduler = CosineDecayRestarts(initial_learning_rate=1e-3, first_decay_steps=20, t_mul=1, alpha=1e-5)
        #optimizer = Adam(learning_rate=scheduler)

        model.compile(optimizer="adam", loss="mae")

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.85, 
                               patience=10, verbose=VERBOSE)

        # save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
        chk_point = ModelCheckpoint(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5', #options=save_locally, 
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=30, 
                           verbose=VERBOSE, mode="min", 
                           restore_best_weights=True)

        model.fit(X_train, y_train, 
                  validation_data=(X_valid, y_valid), 
                  epochs=300,
                  verbose=VERBOSE,
                  batch_size=BATCH_SIZE, 
                  callbacks=[lr, chk_point, es, WandbCallback()])

        # load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
        model = load_model(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5') #options=load_locally

        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
        score = mean_absolute_error(y_true, y_pred)
        print(f"Fold-{fold+1} | OOF Score: {score}")
        count += 1
        all_score += score

        test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
        
        run.finish()
        
        if fold==1:
            break
        
    print(f'CV Score: {all_score/count:<.4f}')
# Out:
# wandb: Currently logged in as: hypknot (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/3jent7hv" target="_blank">fold_0</a></strong> to <a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Epoch 1/300
# 266/266 [==============================] - ETA: 0s - loss: 1.0462
# Epoch 00001: val_loss improved from inf to 0.61432, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 67s 250ms/step - loss: 1.0462 - val_loss: 0.6143
# Epoch 2/300
# 266/266 [==============================] - ETA: 0s - loss: 0.5356
# Epoch 00002: val_loss improved from 0.61432 to 0.60073, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.5356 - val_loss: 0.6007
# Epoch 3/300
# 266/266 [==============================] - ETA: 0s - loss: 0.4617
# Epoch 00003: val_loss improved from 0.60073 to 0.48501, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 235ms/step - loss: 0.4617 - val_loss: 0.4850
# Epoch 4/300
# 266/266 [==============================] - ETA: 0s - loss: 0.4296
# Epoch 00004: val_loss improved from 0.48501 to 0.46628, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.4296 - val_loss: 0.4663
# Epoch 5/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3959
# Epoch 00005: val_loss improved from 0.46628 to 0.35813, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 62s 235ms/step - loss: 0.3959 - val_loss: 0.3581
# Epoch 6/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3791
# Epoch 00006: val_loss did not improve from 0.35813
# 266/266 [==============================] - 62s 231ms/step - loss: 0.3791 - val_loss: 0.3631
# Epoch 7/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3502
# Epoch 00007: val_loss did not improve from 0.35813
# 266/266 [==============================] - 62s 232ms/step - loss: 0.3502 - val_loss: 0.3846
# Epoch 8/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3352
# Epoch 00008: val_loss improved from 0.35813 to 0.33005, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.3352 - val_loss: 0.3300
# Epoch 9/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3181
# Epoch 00009: val_loss did not improve from 0.33005
# 266/266 [==============================] - 62s 232ms/step - loss: 0.3181 - val_loss: 0.3494
# Epoch 10/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3168
# Epoch 00010: val_loss did not improve from 0.33005
# 266/266 [==============================] - 62s 232ms/step - loss: 0.3168 - val_loss: 0.3471
# Epoch 11/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3045
# Epoch 00011: val_loss improved from 0.33005 to 0.31571, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.3045 - val_loss: 0.3157
# Epoch 12/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3049
# Epoch 00012: val_loss did not improve from 0.31571
# 266/266 [==============================] - 62s 232ms/step - loss: 0.3049 - val_loss: 0.3325
# Epoch 13/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2911
# Epoch 00013: val_loss improved from 0.31571 to 0.28615, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2911 - val_loss: 0.2862
# Epoch 14/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2805
# Epoch 00014: val_loss improved from 0.28615 to 0.28515, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2805 - val_loss: 0.2852
# Epoch 15/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2714
# Epoch 00015: val_loss improved from 0.28515 to 0.27600, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2714 - val_loss: 0.2760
# Epoch 16/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2810
# Epoch 00016: val_loss did not improve from 0.27600
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2810 - val_loss: 0.2783
# Epoch 17/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2694
# Epoch 00017: val_loss did not improve from 0.27600
# 266/266 [==============================] - 62s 232ms/step - loss: 0.2694 - val_loss: 0.2902
# Epoch 18/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2781
# Epoch 00018: val_loss did not improve from 0.27600
# 266/266 [==============================] - 62s 232ms/step - loss: 0.2781 - val_loss: 0.2887
# Epoch 19/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2587
# Epoch 00019: val_loss improved from 0.27600 to 0.27397, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2587 - val_loss: 0.2740
# Epoch 20/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2488
# Epoch 00020: val_loss improved from 0.27397 to 0.26610, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2488 - val_loss: 0.2661
# Epoch 21/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2482
# Epoch 00021: val_loss did not improve from 0.26610
# 266/266 [==============================] - 62s 232ms/step - loss: 0.2482 - val_loss: 0.2682
# Epoch 22/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2452
# Epoch 00022: val_loss improved from 0.26610 to 0.24826, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 238ms/step - loss: 0.2452 - val_loss: 0.2483
# Epoch 23/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2371
# Epoch 00023: val_loss improved from 0.24826 to 0.23713, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2371 - val_loss: 0.2371
# Epoch 24/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2310
# Epoch 00024: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2310 - val_loss: 0.2621
# Epoch 25/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2345
# Epoch 00025: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2345 - val_loss: 0.2401
# Epoch 26/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2279
# Epoch 00026: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 232ms/step - loss: 0.2279 - val_loss: 0.2521
# Epoch 27/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2497
# Epoch 00027: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2497 - val_loss: 0.2398
# Epoch 28/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2420
# Epoch 00028: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2420 - val_loss: 0.2653
# Epoch 29/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2289
# Epoch 00029: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2289 - val_loss: 0.2458
# Epoch 30/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2303
# Epoch 00030: val_loss did not improve from 0.23713
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2303 - val_loss: 0.2473
# Epoch 31/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2181
# Epoch 00031: val_loss improved from 0.23713 to 0.22463, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 65s 244ms/step - loss: 0.2181 - val_loss: 0.2246
# Epoch 32/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2242
# Epoch 00032: val_loss did not improve from 0.22463
# 266/266 [==============================] - 64s 241ms/step - loss: 0.2242 - val_loss: 0.2421
# Epoch 33/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2093
# Epoch 00033: val_loss did not improve from 0.22463
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2093 - val_loss: 0.2262
# Epoch 34/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2046
# Epoch 00034: val_loss did not improve from 0.22463
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2046 - val_loss: 0.2506
# Epoch 35/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2187
# Epoch 00035: val_loss improved from 0.22463 to 0.22102, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2187 - val_loss: 0.2210
# Epoch 36/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2021
# Epoch 00036: val_loss improved from 0.22102 to 0.21626, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.2021 - val_loss: 0.2163
# Epoch 37/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1982
# Epoch 00037: val_loss improved from 0.21626 to 0.20842, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.1982 - val_loss: 0.2084
# Epoch 38/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1960
# Epoch 00038: val_loss did not improve from 0.20842
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1960 - val_loss: 0.2450
# Epoch 39/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2053
# Epoch 00039: val_loss did not improve from 0.20842
# 266/266 [==============================] - 62s 233ms/step - loss: 0.2053 - val_loss: 0.2114
# Epoch 40/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1895
# Epoch 00040: val_loss did not improve from 0.20842
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1895 - val_loss: 0.2275
# Epoch 41/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2000
# Epoch 00041: val_loss did not improve from 0.20842
# 266/266 [==============================] - 62s 232ms/step - loss: 0.2000 - val_loss: 0.2247
# Epoch 42/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1927
# Epoch 00042: val_loss did not improve from 0.20842
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1927 - val_loss: 0.2138
# Epoch 43/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1869
# Epoch 00043: val_loss did not improve from 0.20842
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1869 - val_loss: 0.2196
# Epoch 44/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1936
# Epoch 00044: val_loss improved from 0.20842 to 0.20708, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.1936 - val_loss: 0.2071
# Epoch 45/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1807
# Epoch 00045: val_loss did not improve from 0.20708
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1807 - val_loss: 0.2152
# Epoch 46/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1820
# Epoch 00046: val_loss improved from 0.20708 to 0.20435, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.1820 - val_loss: 0.2043
# Epoch 47/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1868
# Epoch 00047: val_loss improved from 0.20435 to 0.20014, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.1868 - val_loss: 0.2001
# Epoch 48/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1779
# Epoch 00048: val_loss did not improve from 0.20014
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1779 - val_loss: 0.2321
# Epoch 49/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1956
# Epoch 00049: val_loss did not improve from 0.20014
# 266/266 [==============================] - 62s 233ms/step - loss: 0.1956 - val_loss: 0.2091
# Epoch 50/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1895
# Epoch 00050: val_loss did not improve from 0.20014
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1895 - val_loss: 0.2091
# Epoch 51/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1757
# Epoch 00051: val_loss improved from 0.20014 to 0.19677, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 235ms/step - loss: 0.1757 - val_loss: 0.1968
# Epoch 52/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1737
# Epoch 00052: val_loss did not improve from 0.19677
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1737 - val_loss: 0.2033
# Epoch 53/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1758
# Epoch 00053: val_loss did not improve from 0.19677
# 266/266 [==============================] - 64s 239ms/step - loss: 0.1758 - val_loss: 0.1992
# Epoch 54/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1766
# Epoch 00054: val_loss did not improve from 0.19677
# 266/266 [==============================] - 64s 242ms/step - loss: 0.1766 - val_loss: 0.2363
# Epoch 55/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1800
# Epoch 00055: val_loss improved from 0.19677 to 0.19394, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 63s 236ms/step - loss: 0.1800 - val_loss: 0.1939
# Epoch 56/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1662
# Epoch 00056: val_loss did not improve from 0.19394
# 266/266 [==============================] - 64s 242ms/step - loss: 0.1662 - val_loss: 0.1950
# Epoch 57/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1670
# Epoch 00057: val_loss improved from 0.19394 to 0.18715, saving model to ./results/1030_tf_lstm+transformer/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 67s 250ms/step - loss: 0.1670 - val_loss: 0.1871
# Epoch 58/300
# 266/266 [==============================] - ETA: 0s - loss: 0.1582
# Epoch 00058: val_loss did not improve from 0.18715
# 266/266 [==============================] - 62s 232ms/step - loss: 0.1582 - val_loss: 0.1923
# Epoch 59/300
# 124/266 [============>.................] - ETA: 31s - loss: 0.1558

# %% [markdown]
# ## Create submission file

# %%
train = pd.read_csv(DATA_DIR + 'train.csv')
test = pd.read_csv(DATA_DIR + 'test.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')

unique_pressures = train["pressure"].unique()
sorted_pressures = np.sort(unique_pressures)
total_pressures_len = len(sorted_pressures)

def find_nearest(prediction):
    '''
    予測値は離散値であるため、学習データにある最も近い離散値に置き換える
    '''
    insert_idx = np.searchsorted(sorted_pressures, prediction)
    if insert_idx == total_pressures_len:
        # If the predicted value is bigger than the highest pressure in the train dataset,
        # return the max value.
        return sorted_pressures[-1]
    elif insert_idx == 0:
        # Same control but for the lower bound.
        return sorted_pressures[0]
    lower_val = sorted_pressures[insert_idx - 1]
    upper_val = sorted_pressures[insert_idx]
    return lower_val if abs(lower_val - prediction) < abs(upper_val - prediction) else upper_val

# %%
submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
submission["pressure"] = sum(test_preds)/5
submission.to_csv(OUTPUT_DIR+'mean_submission.csv', index=False)

# %%
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission["pressure"] = np.round((submission.pressure - P_MIN)/P_STEP) * P_STEP + P_MIN
submission["pressure"] = np.clip(submission.pressure, P_MIN, P_MAX)
submission["pressure"] = submission["pressure"].apply(find_nearest)
submission.to_csv(OUTPUT_DIR+'median_submission.csv', index=False)
