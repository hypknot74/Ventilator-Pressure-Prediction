# %% [markdown]
# ## Import libraries

# %%
import os 

CUDA=2

NAME = '1030_tf_lstm+transformer_ver2'
OUTPUT_DIR = f'./results/{NAME}/'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
DATA_DIR = '../input/ventilator-pressure-prediction/'

# %%
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
#from tensorflow.keras.optimizers.schedules import CosineDecayRestarts
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, LayerNormalization
from tensorflow.keras.layers import Dense, Dropout, Input, Activation
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply
from tensorflow.keras import layers

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Load source datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_in__mean'] = df.groupby(['breath_id'])['u_in'].transform('mean')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"})\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df


print("Train data...\n")
train = add_features(train_df)

print("\nTest data...\n")
test = add_features(test_df)

del train_df
del test_df
gc.collect()
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
# 0

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id','one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

print(f"train: {train.shape} \ntest: {test.shape}")
# Out:
# train: (6036000, 64)
# test: (4024000, 64)

# %%
scaler = RobustScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 64)
# test: (50300, 80, 64)
# targets: (75450, 80)

# %%
pressure = targets.squeeze().reshape(-1,1).astype('float32')

P_MIN = np.min(pressure)
P_MAX = np.max(pressure)
P_STEP = (pressure[1] - pressure[0])[0]
print('Min pressure: {}'.format(P_MIN))
print('Max pressure: {}'.format(P_MAX))
print('Pressure step: {}'.format(P_STEP))
print('Unique values:  {}'.format(np.unique(pressure).shape[0]))

del pressure
gc.collect()
# Out:
# Min pressure: -1.8957443237304688
# Max pressure: 64.82099151611328
# Pressure step: 0.07030248641967773
# Unique values:  950
# 69

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 256
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# Running on 1 replicas
# Batch Size: 256

# %% [markdown]
# ## Keras DNN Model

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res


def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x_tf = x_input
        
    for _ in range(4):
        x_tf = transformer_encoder(x_tf, head_size=256, num_heads=8, ff_dim=1024, dropout=0.2)
    x_tf = Dense(units=256, activation='selu')(x_tf)    
    
    
    # x_emb = Dense(units=1024)(x_input)
    # x_emb = LayerNormalization()(x_emb)
    # x_emb = Activation('selu')(x_emb)
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(LSTM(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(LSTM(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(LSTM(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5, x_tf])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
with tf.device(f'/device:GPU:{CUDA}'):
    model = dnn_model()
    model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 64)]     0
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 80, 64)       128         input_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, 80, 64)       530496      layer_normalization[0][0]
#                                                                  layer_normalization[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 80, 64)       0           multi_head_attention[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 80, 64)]     0           dropout[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 80, 1024)     66560       layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 1024)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 80, 64)       65600       dropout_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 80, 64)]     0           conv1d_1[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, 80, 64)       530496      layer_normalization_2[0][0]
#                                                                  layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80, 64)       0           multi_head_attention_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 80, 64)]     0           dropout_2[0][0]
#                                                                  tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 80, 1024)     66560       layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 80, 1024)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 80, 64)       65600       dropout_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 80, 64)]     0           conv1d_3[0][0]
#                                                                  tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_2 (MultiHe (None, 80, 64)       530496      layer_normalization_4[0][0]
#                                                                  layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 80, 64)       0           multi_head_attention_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 80, 64)]     0           dropout_4[0][0]
#                                                                  tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_5 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 80, 1024)     66560       layer_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 80, 1024)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 80, 1536)     5117952     input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 80, 64)       65600       dropout_5[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 1024)     8392704     bidirectional[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 80, 64)]     0           conv1d_5[0][0]
#                                                                  tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 768)      4328448     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 80, 768)      3248640     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 80, 768)      0           bidirectional_2[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_3 (MultiHe (None, 80, 64)       530496      layer_normalization_6[0][0]
#                                                                  layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 768)      3072        multiply[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 80, 64)       0           multi_head_attention_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      2099200     bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 80, 512)      2099200     batch_normalization[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow [(None, 80, 64)]     0           dropout_6[0][0]
#                                                                  tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 80, 512)      0           bidirectional_3[0][0]
#                                                                  bidirectional_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 80, 64)       128         tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 512)      2048        multiply_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 80, 1024)     66560       layer_normalization_7[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 256)      656384      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 80, 256)      656384      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 1024)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 256)      0           bidirectional_4[0][0]
#                                                                  bidirectional_7[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 80, 64)       65600       dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 256)      1024        multiply_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_7 (TensorFlow [(None, 80, 64)]     0           conv1d_7[0][0]
#                                                                  tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 80, 128)      164352      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 80, 256)      16640       tf_op_layer_AddV2_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80, 2176)     0           bidirectional_4[0][0]
#                                                                  bidirectional_5[0][0]
#                                                                  bidirectional_6[0][0]
#                                                                  bidirectional_7[0][0]
#                                                                  bidirectional_8[0][0]
#                                                                  dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80, 128)      278656      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80, 1)        129         dense_1[0][0]
# ==================================================================================================
# Total params: 29,716,481
# Trainable params: 29,713,409
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file=OUTPUT_DIR+'Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
import wandb
from wandb.keras import WandbCallback




with tf.device(f'/device:GPU:{CUDA}'):
    VERBOSE = 1
    test_preds = []
    kf = KFold(n_splits=10, shuffle=True, random_state=2021)

    all_score = 0
    count = 0
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        run = wandb.init(project="Ventilator-Pressure-Public-tf", 
                     name=f'fold_{fold}',
                     config={"hyper": "parameter"},
                     group=NAME,
                    job_type='train')
        
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]

        model = dnn_model()

        #scheduler = CosineDecayRestarts(initial_learning_rate=1e-3, first_decay_steps=20, t_mul=1, alpha=1e-5)
        #optimizer = Adam(learning_rate=scheduler)

        model.compile(optimizer="adam", loss="mae")

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.85, 
                               patience=10, verbose=VERBOSE)

        # save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
        chk_point = ModelCheckpoint(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5', #options=save_locally, 
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=30, 
                           verbose=VERBOSE, mode="min", 
                           restore_best_weights=True)

        model.fit(X_train, y_train, 
                  validation_data=(X_valid, y_valid), 
                  epochs=300,
                  verbose=VERBOSE,
                  batch_size=BATCH_SIZE, 
                  callbacks=[lr, chk_point, es, WandbCallback()])

        # load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
        model = load_model(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5') #options=load_locally

        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
        score = mean_absolute_error(y_true, y_pred)
        print(f"Fold-{fold+1} | OOF Score: {score}")
        count += 1
        all_score += score

        test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
        
        run.finish()
        
        if fold==1:
            break
        
    print(f'CV Score: {all_score/count:<.4f}')
# Out:
# wandb: Currently logged in as: hypknot (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/kbxeszl4" target="_blank">fold_0</a></strong> to <a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Epoch 1/300
# 266/266 [==============================] - ETA: 0s - loss: 1.0221
# Epoch 00001: val_loss improved from inf to 0.76482, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 87s 326ms/step - loss: 1.0221 - val_loss: 0.7648
# Epoch 2/300
# 266/266 [==============================] - ETA: 0s - loss: 0.5321
# Epoch 00002: val_loss improved from 0.76482 to 0.61442, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.5321 - val_loss: 0.6144
# Epoch 3/300
# 266/266 [==============================] - ETA: 0s - loss: 0.4624
# Epoch 00003: val_loss improved from 0.61442 to 0.47782, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.4624 - val_loss: 0.4778
# Epoch 4/300
# 266/266 [==============================] - ETA: 0s - loss: 0.4262
# Epoch 00004: val_loss did not improve from 0.47782
# 266/266 [==============================] - 82s 307ms/step - loss: 0.4262 - val_loss: 0.4926
# Epoch 5/300
# 266/266 [==============================] - ETA: 0s - loss: 0.4022
# Epoch 00005: val_loss improved from 0.47782 to 0.38909, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.4022 - val_loss: 0.3891
# Epoch 6/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3718
# Epoch 00006: val_loss improved from 0.38909 to 0.38367, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 313ms/step - loss: 0.3718 - val_loss: 0.3837
# Epoch 7/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3469
# Epoch 00007: val_loss improved from 0.38367 to 0.38024, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 311ms/step - loss: 0.3469 - val_loss: 0.3802
# Epoch 8/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3392
# Epoch 00008: val_loss improved from 0.38024 to 0.35914, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.3392 - val_loss: 0.3591
# Epoch 9/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3334
# Epoch 00009: val_loss improved from 0.35914 to 0.32949, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.3334 - val_loss: 0.3295
# Epoch 10/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3148
# Epoch 00010: val_loss improved from 0.32949 to 0.32785, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.3148 - val_loss: 0.3278
# Epoch 11/300
# 266/266 [==============================] - ETA: 0s - loss: 0.3029
# Epoch 00011: val_loss improved from 0.32785 to 0.29307, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.3029 - val_loss: 0.2931
# Epoch 12/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2960
# Epoch 00012: val_loss did not improve from 0.29307
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2960 - val_loss: 0.2945
# Epoch 13/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2866
# Epoch 00013: val_loss improved from 0.29307 to 0.27985, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2866 - val_loss: 0.2798
# Epoch 14/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2796
# Epoch 00014: val_loss improved from 0.27985 to 0.27576, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2796 - val_loss: 0.2758
# Epoch 15/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2715
# Epoch 00015: val_loss did not improve from 0.27576
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2715 - val_loss: 0.2805
# Epoch 16/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2790
# Epoch 00016: val_loss did not improve from 0.27576
# 266/266 [==============================] - 82s 308ms/step - loss: 0.2790 - val_loss: 0.3213
# Epoch 17/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2665
# Epoch 00017: val_loss improved from 0.27576 to 0.27462, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 85s 321ms/step - loss: 0.2665 - val_loss: 0.2746
# Epoch 18/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2564
# Epoch 00018: val_loss improved from 0.27462 to 0.25701, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 85s 319ms/step - loss: 0.2564 - val_loss: 0.2570
# Epoch 19/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2511
# Epoch 00019: val_loss did not improve from 0.25701
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2511 - val_loss: 0.2768
# Epoch 20/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2529
# Epoch 00020: val_loss improved from 0.25701 to 0.25512, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2529 - val_loss: 0.2551
# Epoch 21/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2370
# Epoch 00021: val_loss did not improve from 0.25512
# 266/266 [==============================] - 81s 306ms/step - loss: 0.2370 - val_loss: 0.2887
# Epoch 22/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2502
# Epoch 00022: val_loss improved from 0.25512 to 0.24626, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2502 - val_loss: 0.2463
# Epoch 23/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2387
# Epoch 00023: val_loss improved from 0.24626 to 0.24278, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2387 - val_loss: 0.2428
# Epoch 24/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2406
# Epoch 00024: val_loss did not improve from 0.24278
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2406 - val_loss: 0.2455
# Epoch 25/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2327
# Epoch 00025: val_loss did not improve from 0.24278
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2327 - val_loss: 0.2441
# Epoch 26/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2230
# Epoch 00026: val_loss improved from 0.24278 to 0.23448, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2230 - val_loss: 0.2345
# Epoch 27/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2273
# Epoch 00027: val_loss did not improve from 0.23448
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2273 - val_loss: 0.2843
# Epoch 28/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2248
# Epoch 00028: val_loss improved from 0.23448 to 0.22395, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 311ms/step - loss: 0.2248 - val_loss: 0.2240
# Epoch 29/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2145
# Epoch 00029: val_loss did not improve from 0.22395
# 266/266 [==============================] - 82s 307ms/step - loss: 0.2145 - val_loss: 0.2276
# Epoch 30/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2192
# Epoch 00030: val_loss did not improve from 0.22395
# 266/266 [==============================] - 82s 308ms/step - loss: 0.2192 - val_loss: 0.2450
# Epoch 31/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2196
# Epoch 00031: val_loss did not improve from 0.22395
# 266/266 [==============================] - 82s 308ms/step - loss: 0.2196 - val_loss: 0.2369
# Epoch 32/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2051
# Epoch 00032: val_loss improved from 0.22395 to 0.22335, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2051 - val_loss: 0.2234
# Epoch 33/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2128
# Epoch 00033: val_loss improved from 0.22335 to 0.21697, saving model to ./results/1030_tf_lstm+transformer_ver2/./Bidirect_LSTM_model_2021_1C.h5
# 266/266 [==============================] - 83s 312ms/step - loss: 0.2128 - val_loss: 0.2170
# Epoch 34/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2100
# Epoch 00034: val_loss did not improve from 0.21697
# 266/266 [==============================] - 84s 317ms/step - loss: 0.2100 - val_loss: 0.2384
# Epoch 35/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2151
# Epoch 00035: val_loss did not improve from 0.21697
# 266/266 [==============================] - 83s 310ms/step - loss: 0.2151 - val_loss: 0.2414
# Epoch 36/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2125
# Epoch 00036: val_loss did not improve from 0.21697
# 266/266 [==============================] - 85s 320ms/step - loss: 0.2125 - val_loss: 0.2246
# Epoch 37/300
# 266/266 [==============================] - ETA: 0s - loss: 0.2035
# Epoch 00037: val_loss did not improve from 0.21697
# 266/266 [==============================] - 84s 316ms/step - loss: 0.2035 - val_loss: 0.2222
# Epoch 38/300
#  66/266 [======>.......................] - ETA: 58s - loss: 0.1917

# %% [markdown]
# ## Create submission file

# %%
train = pd.read_csv(DATA_DIR + 'train.csv')
test = pd.read_csv(DATA_DIR + 'test.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')

unique_pressures = train["pressure"].unique()
sorted_pressures = np.sort(unique_pressures)
total_pressures_len = len(sorted_pressures)

def find_nearest(prediction):
    '''
    予測値は離散値であるため、学習データにある最も近い離散値に置き換える
    '''
    insert_idx = np.searchsorted(sorted_pressures, prediction)
    if insert_idx == total_pressures_len:
        # If the predicted value is bigger than the highest pressure in the train dataset,
        # return the max value.
        return sorted_pressures[-1]
    elif insert_idx == 0:
        # Same control but for the lower bound.
        return sorted_pressures[0]
    lower_val = sorted_pressures[insert_idx - 1]
    upper_val = sorted_pressures[insert_idx]
    return lower_val if abs(lower_val - prediction) < abs(upper_val - prediction) else upper_val

# %%
submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
submission["pressure"] = sum(test_preds)/5
submission.to_csv(OUTPUT_DIR+'mean_submission.csv', index=False)

# %%
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission["pressure"] = np.round((submission.pressure - P_MIN)/P_STEP) * P_STEP + P_MIN
submission["pressure"] = np.clip(submission.pressure, P_MIN, P_MAX)
submission["pressure"] = submission["pressure"].apply(find_nearest)
submission.to_csv(OUTPUT_DIR+'median_submission.csv', index=False)
