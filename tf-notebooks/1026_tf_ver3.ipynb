# %% [markdown]
# ## Import libraries

# %%
import os 

CUDA=3

NAME = '1026_tf_ver3'
OUTPUT_DIR = f'./results/{NAME}/'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
DATA_DIR = '../input/ventilator-pressure-prediction/'

# %%
import gc
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
#from tensorflow.keras.optimizers.schedules import CosineDecayRestarts
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization, LayerNormalization
from tensorflow.keras.layers import Dense, Dropout, Input, Activation
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Load source datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_in__mean'] = df.groupby(['breath_id'])['u_in'].transform('mean')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"})\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df


print("Train data...\n")
train = add_features(train_df)

print("\nTest data...\n")
test = add_features(test_df)

del train_df
del test_df
gc.collect()
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
# 0

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id','one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

print(f"train: {train.shape} \ntest: {test.shape}")
# Out:
# train: (6036000, 64)
# test: (4024000, 64)

# %%
scaler = RobustScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 64)
# test: (50300, 80, 64)
# targets: (75450, 80)

# %%
pressure = targets.squeeze().reshape(-1,1).astype('float32')

P_MIN = np.min(pressure)
P_MAX = np.max(pressure)
P_STEP = (pressure[1] - pressure[0])[0]
print('Min pressure: {}'.format(P_MIN))
print('Max pressure: {}'.format(P_MAX))
print('Pressure step: {}'.format(P_STEP))
print('Unique values:  {}'.format(np.unique(pressure).shape[0]))

del pressure
gc.collect()
# Out:
# Min pressure: -1.8957443237304688
# Max pressure: 64.82099151611328
# Pressure step: 0.07030248641967773
# Unique values:  950
# 69

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 512
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# Running on 1 replicas
# Batch Size: 512

# %% [markdown]
# ## Keras DNN Model

# %%
def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    # x_emb = Dense(units=1024)(x_input)
    # x_emb = LayerNormalization()(x_emb)
    # x_emb = Activation('selu')(x_emb)
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(GRU(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(GRU(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(LSTM(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(LSTM(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(LSTM(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
with tf.device(f'/device:GPU:{CUDA}'):
    model = dnn_model()
    model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 64)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 80, 1536)     5117952     input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 1024)     8392704     bidirectional[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 768)      3248640     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 80, 768)      4328448     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 80, 768)      0           bidirectional_2[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 768)      3072        multiply[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      1575936     bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 80, 512)      2099200     batch_normalization[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 80, 512)      0           bidirectional_3[0][0]
#                                                                  bidirectional_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 512)      2048        multiply_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 256)      493056      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 80, 256)      656384      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 256)      0           bidirectional_4[0][0]
#                                                                  bidirectional_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 256)      1024        multiply_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 80, 128)      164352      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80, 1920)     0           bidirectional_4[0][0]
#                                                                  bidirectional_5[0][0]
#                                                                  bidirectional_6[0][0]
#                                                                  bidirectional_7[0][0]
#                                                                  bidirectional_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 80, 128)      245888      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80, 1)        129         dense[0][0]
# ==================================================================================================
# Total params: 26,328,833
# Trainable params: 26,325,761
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file=OUTPUT_DIR+'Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
import wandb
from wandb.keras import WandbCallback




with tf.device(f'/device:GPU:{CUDA}'):
    VERBOSE = 1
    test_preds = []
    kf = KFold(n_splits=5, shuffle=True, random_state=2021)

    all_score = 0
    count = 0
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        run = wandb.init(project="Ventilator-Pressure-Public-tf", 
                     name=f'fold_{fold}',
                     config={"hyper": "parameter"},
                     group=NAME,
                    job_type='train')
        
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]

        model = dnn_model()

        #scheduler = CosineDecayRestarts(initial_learning_rate=1e-3, first_decay_steps=20, t_mul=1, alpha=1e-5)
        #optimizer = Adam(learning_rate=scheduler)

        model.compile(optimizer="adam", loss="mae")

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.85, 
                               patience=10, verbose=VERBOSE)

        # save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
        chk_point = ModelCheckpoint(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5', #options=save_locally, 
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=30, 
                           verbose=VERBOSE, mode="min", 
                           restore_best_weights=True)

        model.fit(X_train, y_train, 
                  validation_data=(X_valid, y_valid), 
                  epochs=300,
                  verbose=VERBOSE,
                  batch_size=BATCH_SIZE, 
                  callbacks=[lr, chk_point, es, WandbCallback()])

        # load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
        model = load_model(OUTPUT_DIR+f'./Bidirect_LSTM_model_2021_{fold+1}C.h5') #options=load_locally

        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
        score = mean_absolute_error(y_true, y_pred)
        print(f"Fold-{fold+1} | OOF Score: {score}")
        count += 1
        all_score += score

        test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
        
        run.finish()
        
    print(f'CV Score: {all_score/count:<.4f}')
# Out:
# wandb: Currently logged in as: hypknot (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf/runs/2k6lr0i3" target="_blank">fold_0</a></strong> to <a href="https://wandb.ai/hypknot/Ventilator-Pressure-Public-tf" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Epoch 1/300
# 118/118 [==============================] - ETA: 0s - loss: 1.5297
# Epoch 00001: val_loss improved from inf to 1.90831, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 29s 245ms/step - loss: 1.5297 - val_loss: 1.9083
# Epoch 2/300
# 118/118 [==============================] - ETA: 0s - loss: 0.6564
# Epoch 00002: val_loss improved from 1.90831 to 1.31361, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 217ms/step - loss: 0.6564 - val_loss: 1.3136
# Epoch 3/300
# 118/118 [==============================] - ETA: 0s - loss: 0.5275
# Epoch 00003: val_loss improved from 1.31361 to 0.56929, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.5275 - val_loss: 0.5693
# Epoch 4/300
# 118/118 [==============================] - ETA: 0s - loss: 0.5007
# Epoch 00004: val_loss did not improve from 0.56929
# 118/118 [==============================] - 25s 212ms/step - loss: 0.5007 - val_loss: 0.7523
# Epoch 5/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4379
# Epoch 00005: val_loss improved from 0.56929 to 0.53517, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.4379 - val_loss: 0.5352
# Epoch 6/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4450
# Epoch 00006: val_loss improved from 0.53517 to 0.49161, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.4450 - val_loss: 0.4916
# Epoch 7/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4045
# Epoch 00007: val_loss improved from 0.49161 to 0.37975, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.4045 - val_loss: 0.3797
# Epoch 8/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3857
# Epoch 00008: val_loss did not improve from 0.37975
# 118/118 [==============================] - 25s 213ms/step - loss: 0.3857 - val_loss: 0.4346
# Epoch 9/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3812
# Epoch 00009: val_loss did not improve from 0.37975
# 118/118 [==============================] - 25s 212ms/step - loss: 0.3812 - val_loss: 0.5202
# Epoch 10/300
# 118/118 [==============================] - ETA: 0s - loss: 0.4060
# Epoch 00010: val_loss did not improve from 0.37975
# 118/118 [==============================] - 25s 212ms/step - loss: 0.4060 - val_loss: 0.3955
# Epoch 11/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3593
# Epoch 00011: val_loss improved from 0.37975 to 0.36918, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3593 - val_loss: 0.3692
# Epoch 12/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3458
# Epoch 00012: val_loss did not improve from 0.36918
# 118/118 [==============================] - 25s 212ms/step - loss: 0.3458 - val_loss: 0.5493
# Epoch 13/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3446
# Epoch 00013: val_loss improved from 0.36918 to 0.33151, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.3446 - val_loss: 0.3315
# Epoch 14/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3321
# Epoch 00014: val_loss did not improve from 0.33151
# 118/118 [==============================] - 25s 213ms/step - loss: 0.3321 - val_loss: 0.3528
# Epoch 15/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3067
# Epoch 00015: val_loss did not improve from 0.33151
# 118/118 [==============================] - 25s 213ms/step - loss: 0.3067 - val_loss: 0.3465
# Epoch 16/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3046
# Epoch 00016: val_loss improved from 0.33151 to 0.29562, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.3046 - val_loss: 0.2956
# Epoch 17/300
# 118/118 [==============================] - ETA: 0s - loss: 0.3023
# Epoch 00017: val_loss did not improve from 0.29562
# 118/118 [==============================] - 25s 213ms/step - loss: 0.3023 - val_loss: 0.3216
# Epoch 18/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2979
# Epoch 00018: val_loss did not improve from 0.29562
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2979 - val_loss: 0.3715
# Epoch 19/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2881
# Epoch 00019: val_loss did not improve from 0.29562
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2881 - val_loss: 0.3497
# Epoch 20/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2845
# Epoch 00020: val_loss did not improve from 0.29562
# 118/118 [==============================] - 25s 213ms/step - loss: 0.2845 - val_loss: 0.3322
# Epoch 21/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2867
# Epoch 00021: val_loss did not improve from 0.29562
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2867 - val_loss: 0.2971
# Epoch 22/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2867
# Epoch 00022: val_loss did not improve from 0.29562
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2867 - val_loss: 0.3507
# Epoch 23/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2723
# Epoch 00023: val_loss improved from 0.29562 to 0.26742, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.2723 - val_loss: 0.2674
# Epoch 24/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2699
# Epoch 00024: val_loss did not improve from 0.26742
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2699 - val_loss: 0.3122
# Epoch 25/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2522
# Epoch 00025: val_loss improved from 0.26742 to 0.26319, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.2522 - val_loss: 0.2632
# Epoch 26/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2657
# Epoch 00026: val_loss did not improve from 0.26319
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2657 - val_loss: 0.2812
# Epoch 27/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2654
# Epoch 00027: val_loss improved from 0.26319 to 0.24567, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.2654 - val_loss: 0.2457
# Epoch 28/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2479
# Epoch 00028: val_loss did not improve from 0.24567
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2479 - val_loss: 0.2777
# Epoch 29/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2702
# Epoch 00029: val_loss did not improve from 0.24567
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2702 - val_loss: 0.2725
# Epoch 30/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2622
# Epoch 00030: val_loss did not improve from 0.24567
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2622 - val_loss: 0.2790
# Epoch 31/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2593
# Epoch 00031: val_loss did not improve from 0.24567
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2593 - val_loss: 0.2568
# Epoch 32/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2423
# Epoch 00032: val_loss improved from 0.24567 to 0.23581, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.2423 - val_loss: 0.2358
# Epoch 33/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2409
# Epoch 00033: val_loss did not improve from 0.23581
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2409 - val_loss: 0.2744
# Epoch 34/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2432
# Epoch 00034: val_loss did not improve from 0.23581
# 118/118 [==============================] - 25s 213ms/step - loss: 0.2432 - val_loss: 0.2488
# Epoch 35/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2469
# Epoch 00035: val_loss did not improve from 0.23581
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2469 - val_loss: 0.2537
# Epoch 36/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2480
# Epoch 00036: val_loss did not improve from 0.23581
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2480 - val_loss: 0.2647
# Epoch 37/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2375
# Epoch 00037: val_loss did not improve from 0.23581
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2375 - val_loss: 0.2573
# Epoch 38/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2109
# Epoch 00043: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2109 - val_loss: 0.2400
# Epoch 44/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2091
# Epoch 00044: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2091 - val_loss: 0.2410
# Epoch 45/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2061
# Epoch 00045: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 213ms/step - loss: 0.2061 - val_loss: 0.2225
# Epoch 46/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2073
# Epoch 00046: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2073 - val_loss: 0.2419
# Epoch 47/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2132
# Epoch 00047: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2132 - val_loss: 0.2327
# Epoch 48/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2101
# Epoch 00048: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2101 - val_loss: 0.2348
# Epoch 49/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2656
# Epoch 00049: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2656 - val_loss: 0.2473
# Epoch 50/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2333
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 0.0008500000403728336.
#
# Epoch 00050: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2333 - val_loss: 0.2383
# Epoch 51/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2158
# Epoch 00051: val_loss did not improve from 0.21592
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2158 - val_loss: 0.2198
# Epoch 52/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2024
# Epoch 00052: val_loss improved from 0.21592 to 0.21306, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.2024 - val_loss: 0.2131
# Epoch 53/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1965
# Epoch 00053: val_loss improved from 0.21306 to 0.20462, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.1965 - val_loss: 0.2046
# Epoch 54/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1885
# Epoch 00054: val_loss did not improve from 0.20462
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1885 - val_loss: 0.2190
# Epoch 55/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1962
# Epoch 00055: val_loss did not improve from 0.20462
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1962 - val_loss: 0.2070
# Epoch 56/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1936
# Epoch 00056: val_loss did not improve from 0.20462
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1936 - val_loss: 0.2079
# Epoch 57/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2022
# Epoch 00057: val_loss did not improve from 0.20462
# 118/118 [==============================] - 25s 212ms/step - loss: 0.2022 - val_loss: 0.2536
# Epoch 58/300
# 118/118 [==============================] - ETA: 0s - loss: 0.2001
# Epoch 00058: val_loss improved from 0.20462 to 0.20434, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.2001 - val_loss: 0.2043
# Epoch 59/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1870
# Epoch 00059: val_loss did not improve from 0.20434
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1870 - val_loss: 0.2081
# Epoch 60/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1890
# Epoch 00060: val_loss improved from 0.20434 to 0.19650, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.1890 - val_loss: 0.1965
# Epoch 61/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1799
# Epoch 00061: val_loss did not improve from 0.19650
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1799 - val_loss: 0.2113
# Epoch 62/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1765
# Epoch 00062: val_loss improved from 0.19650 to 0.19234, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.1765 - val_loss: 0.1923
# Epoch 63/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1842
# Epoch 00063: val_loss did not improve from 0.19234
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1842 - val_loss: 0.1979
# Epoch 64/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1767
# Epoch 00064: val_loss did not improve from 0.19234
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1767 - val_loss: 0.2124
# Epoch 65/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1931
# Epoch 00065: val_loss did not improve from 0.19234
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1931 - val_loss: 0.2350
# Epoch 66/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1783
# Epoch 00066: val_loss did not improve from 0.19234
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1783 - val_loss: 0.1945
# Epoch 67/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1829
# Epoch 00067: val_loss did not improve from 0.19234
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1829 - val_loss: 0.2004
# Epoch 68/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1714
# Epoch 00068: val_loss improved from 0.19234 to 0.18988, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.1714 - val_loss: 0.1899
# Epoch 69/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1705
# Epoch 00069: val_loss did not improve from 0.18988
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1705 - val_loss: 0.2224
# Epoch 70/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1790
# Epoch 00070: val_loss did not improve from 0.18988
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1790 - val_loss: 0.2061
# Epoch 71/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1883
# Epoch 00071: val_loss did not improve from 0.18988
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1883 - val_loss: 0.1923
# Epoch 72/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1698
# Epoch 00072: val_loss did not improve from 0.18988
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1698 - val_loss: 0.1943
# Epoch 73/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1668
# Epoch 00073: val_loss improved from 0.18988 to 0.18240, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.1668 - val_loss: 0.1824
# Epoch 74/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1617
# Epoch 00074: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1617 - val_loss: 0.2130
# Epoch 75/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1779
# Epoch 00075: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1779 - val_loss: 0.1935
# Epoch 76/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1714
# Epoch 00076: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1714 - val_loss: 0.2112
# Epoch 77/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1753
# Epoch 00077: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1753 - val_loss: 0.1968
# Epoch 78/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1653
# Epoch 00078: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1653 - val_loss: 0.1909
# Epoch 79/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1643
# Epoch 00079: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1643 - val_loss: 0.1901
# Epoch 80/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1619
# Epoch 00080: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1619 - val_loss: 0.1920
# Epoch 81/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1566
# Epoch 00081: val_loss did not improve from 0.18240
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1566 - val_loss: 0.1948
# Epoch 82/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1549
# Epoch 00082: val_loss improved from 0.18240 to 0.17987, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 223ms/step - loss: 0.1549 - val_loss: 0.1799
# Epoch 83/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1508
# Epoch 00083: val_loss did not improve from 0.17987
# 118/118 [==============================] - 25s 215ms/step - loss: 0.1508 - val_loss: 0.1840
# Epoch 84/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1550
# Epoch 00084: val_loss did not improve from 0.17987
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1550 - val_loss: 0.1814
# Epoch 85/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1541
# Epoch 00085: val_loss did not improve from 0.17987
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1541 - val_loss: 0.1820
# Epoch 86/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1477
# Epoch 00086: val_loss improved from 0.17987 to 0.17339, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 219ms/step - loss: 0.1477 - val_loss: 0.1734
# Epoch 87/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1535
# Epoch 00087: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1535 - val_loss: 0.1901
# Epoch 88/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1564
# Epoch 00088: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1564 - val_loss: 0.1793
# Epoch 89/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1634
# Epoch 00089: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1634 - val_loss: 0.1933
# Epoch 90/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1585
# Epoch 00090: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1585 - val_loss: 0.1823
# Epoch 91/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1712
# Epoch 00091: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1712 - val_loss: 0.2242
# Epoch 92/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1709
# Epoch 00092: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1709 - val_loss: 0.1962
# Epoch 93/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1546
# Epoch 00093: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1546 - val_loss: 0.2330
# Epoch 94/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1778
# Epoch 00094: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1778 - val_loss: 0.1959
# Epoch 95/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1551
# Epoch 00095: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1551 - val_loss: 0.1821
# Epoch 96/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1481
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 0.0007225000590551645.
#
# Epoch 00096: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1481 - val_loss: 0.1773
# Epoch 97/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1391
# Epoch 00097: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1391 - val_loss: 0.1776
# Epoch 98/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1370
# Epoch 00098: val_loss did not improve from 0.17339
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1370 - val_loss: 0.1844
# Epoch 99/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1439
# Epoch 00099: val_loss improved from 0.17339 to 0.17180, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1439 - val_loss: 0.1718
# Epoch 100/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1395
# Epoch 00100: val_loss did not improve from 0.17180
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1395 - val_loss: 0.1859
# Epoch 101/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1392
# Epoch 00101: val_loss did not improve from 0.17180
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1392 - val_loss: 0.1730
# Epoch 102/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1331
# Epoch 00102: val_loss improved from 0.17180 to 0.17150, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 26s 218ms/step - loss: 0.1331 - val_loss: 0.1715
# Epoch 103/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1334
# Epoch 00103: val_loss did not improve from 0.17150
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1334 - val_loss: 0.1784
# Epoch 104/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1315
# Epoch 00104: val_loss did not improve from 0.17150
# 118/118 [==============================] - 25s 213ms/step - loss: 0.1315 - val_loss: 0.1719
# Epoch 105/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1300
# Epoch 00105: val_loss did not improve from 0.17150
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1300 - val_loss: 0.1759
# Epoch 106/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1281
# Epoch 00106: val_loss improved from 0.17150 to 0.16971, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 226ms/step - loss: 0.1281 - val_loss: 0.1697
# Epoch 107/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1262
# Epoch 00107: val_loss improved from 0.16971 to 0.16742, saving model to ./results/1026_tf_ver3/./Bidirect_LSTM_model_2021_1C.h5
# 118/118 [==============================] - 27s 226ms/step - loss: 0.1262 - val_loss: 0.1674
# Epoch 108/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1260
# Epoch 00108: val_loss did not improve from 0.16742
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1260 - val_loss: 0.1698
# Epoch 109/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1247
# Epoch 00109: val_loss did not improve from 0.16742
# 118/118 [==============================] - 26s 224ms/step - loss: 0.1247 - val_loss: 0.1702
# Epoch 110/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1236
# Epoch 00110: val_loss did not improve from 0.16742
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1236 - val_loss: 0.1693
# Epoch 111/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1247
# Epoch 00111: val_loss did not improve from 0.16742
# 118/118 [==============================] - 25s 212ms/step - loss: 0.1247 - val_loss: 0.1689
# Epoch 112/300
# 118/118 [==============================] - ETA: 0s - loss: 0.1239

# %% [markdown]
# ## Create submission file

# %%
train = pd.read_csv(DATA_DIR + 'train.csv')
test = pd.read_csv(DATA_DIR + 'test.csv')
sub = pd.read_csv(DATA_DIR + 'sample_submission.csv')

unique_pressures = train["pressure"].unique()
sorted_pressures = np.sort(unique_pressures)
total_pressures_len = len(sorted_pressures)

def find_nearest(prediction):
    '''
    予測値は離散値であるため、学習データにある最も近い離散値に置き換える
    '''
    insert_idx = np.searchsorted(sorted_pressures, prediction)
    if insert_idx == total_pressures_len:
        # If the predicted value is bigger than the highest pressure in the train dataset,
        # return the max value.
        return sorted_pressures[-1]
    elif insert_idx == 0:
        # Same control but for the lower bound.
        return sorted_pressures[0]
    lower_val = sorted_pressures[insert_idx - 1]
    upper_val = sorted_pressures[insert_idx]
    return lower_val if abs(lower_val - prediction) < abs(upper_val - prediction) else upper_val

# %%
submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
submission["pressure"] = sum(test_preds)/5
submission.to_csv(OUTPUT_DIR+'mean_submission.csv', index=False)

# %%
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission["pressure"] = np.round((submission.pressure - P_MIN)/P_STEP) * P_STEP + P_MIN
submission["pressure"] = np.clip(submission.pressure, P_MIN, P_MAX)
submission["pressure"] = submission["pressure"].apply(find_nearest)
submission.to_csv(OUTPUT_DIR+'median_submission.csv', index=False)
